# %%
print("Hello World")
# Out:
# Hello World

# %%
print("İstanbul - İzmir - Ankara")
print("İstanbul", "İzmir", "Ankara")
print("İstanbul", "İzmir", "Ankara", sep=" - ")
print("İstanbul", "İzmir", "Ankara", sep=" - ")
print("-"* 25)
print("İstanbul\nİzmir\nAnkara")
# Out:
# İstanbul - İzmir - Ankara
# İstanbul İzmir Ankara
# İstanbul - İzmir - Ankara
# İstanbul - İzmir - Ankara
# -------------------------
# İstanbul
# İzmir
# Ankara

# %%
print('Turkcell 101\'deki ilk dersimize hoş geldiniz!')
print("Turkcell 101'deki ilk dersimize hoş geldiniz!")
print("Turkcell'deki ilk kurs \"Python 101\"")
# Out:
# Turkcell 101'deki ilk dersimize hoş geldiniz!
# Turkcell 101'deki ilk dersimize hoş geldiniz!
# Turkcell'deki ilk kurs "Python 101"

# %%
print("Python" + " " + "Eğitimi")
# Out:
# Python Eğitimi

# %%
print(r"C:\Users\byt\Desktop\Python\turkcell_101.ipynb")
# Out:
# C:\Users\byt\Desktop\Python\turkcell_101.ipynb

# %%
# + - % * / ** // 

print(2 + 3)
print(2 - 3)
print(2 * 3)
print(2 / 3)
print(2 ** 3)
print(2 // 3)
print(10 % 3)
# Out:
# 5
# -1
# 6
# 0.6666666666666666
# 8
# 0
# 1

# %%
print((8**2 + 5 * 3 + 2) * 5 - 15 / 3)
# Out:
# 400.0

# %%
print(3.1 + 4.2)
# Out:
# 7.300000000000001

# %%
print("Python", end = " ")
# Out:
# Python

# %%
print("Fatih", "Sultan", "Mehmet", sep = " ")
# Out:
# Fatih Sultan Mehmet

# %%
print(7,5,2024, sep = "/")
# Out:
# 7/5/2024

# %%
print("01","05",2025, sep = "/")
# Out:
# 01/05/2025

# %%
print(*"TC")
print(*"TC", sep = ".")
print("T","C", sep = ".")
# Out:
# T C
# T.C
# T.C

# %%
# .format() methodu kullanımı

print("Adı : Fatih Sultan "
      "Soyadı : Mehmet "
      "Doğum Yılı : 1432")

print("Adı : {} Soyadı : {} Doğum Yılı : {}".format("Fatih Sultan", "Mehmet", 1432))
print("Adı : {} Soyadı : {} Doğum Yılı : {}".format("Kanuni Sultan", "Süleyman", 1494))
# Out:
# Adı : Fatih Sultan Soyadı : Mehmet Doğum Yılı : 1432
# Adı : Fatih Sultan Soyadı : Mehmet Doğum Yılı : 1432
# Adı : Kanuni Sultan Soyadı : Süleyman Doğum Yılı : 1494

# %%
help(print)
help(str)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.
#
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to 'utf-8'.
#  |  errors defaults to 'strict'.
#  |
# ...

# %%
sayi1 = 10
sayi2 = 20

print(sayi1 * 5)
print(sayi2 * 2)

print(sayi1.is_integer())
print("deneme".isalpha())
print("deneme2".isidentifier())

print("deneme".isupper())
print("DENEME".isupper())
# Out:
# 50
# 40
# True
# True
# True
# False
# True

# %%
sayi1 = 158
sayi2 = 217

print("Toplama :" , sayi1 + sayi2)
print("Çıkarma :" , sayi1 - sayi2)
print("Çarpma :" , sayi1 * sayi2)
print("Bölme :" , sayi1 / sayi2)
print("Kalan :" , sayi1 % sayi2)
print("Üs :" , sayi1 ** 2)
print("Tam Bölme :" , sayi1 // 2)
# Out:
# Toplama : 375
# Çıkarma : -59
# Çarpma : 34286
# Bölme : 0.728110599078341
# Kalan : 158
# Üs : 24964
# Tam Bölme : 79

# %%
sayi1 = 158
sayi2 = 217
sayi3 = 184.25

print(type(sayi1))
print(type(sayi2))
print(type(sayi3))

print(id(sayi1))
print(id(sayi2))
print(id(sayi3))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'float'>
# 4321100640
# 4321102528
# 4438856656

# %%
sayi1 = 15.4
sayi2 = 16.3

print("Toplama :" , sayi1 + sayi2)
print("Çıkarma :" , sayi1 - sayi2)
print("Çarpma :" , sayi1 * sayi2)
print("Bölme :" , sayi1 / sayi2)

print(sayi1, type(sayi1))
print(sayi2, type(sayi2))

sayi3 = 15.0
print(sayi3, type(sayi3))

sayi4 = 15
print(sayi4, type(sayi4))
# Out:
# Toplama : 31.700000000000003
# Çıkarma : -0.9000000000000004
# Çarpma : 251.02
# Bölme : 0.9447852760736196
# 15.4 <class 'float'>
# 16.3 <class 'float'>
# 15.0 <class 'float'>
# 15 <class 'int'>

# %%
isim = "Berkay"
soyad = "Turan"

print(isim, type(isim))
print(soyad, type(soyad))

print(len(isim))
print(len(soyad))

print(isim + " " + soyad)
print(isim, soyad)

yapisikIsim = isim + soyad
print(yapisikIsim)

print(yapisikIsim[0], yapisikIsim[4],yapisikIsim[7], yapisikIsim[10])
# Out:
# Berkay <class 'str'>
# Turan <class 'str'>
# 6
# 5
# Berkay Turan
# Berkay Turan
# BerkayTuran
# B a u n

# %%
kelime = "Ballack"
print(kelime)


kelime = "M" + kelime[1:]
print(kelime)
# Out:
# Ballack
# Mallack

# %%
takim = "Fenerbahçe"

print(takim[0:5])
print(takim[5:])
print(takim[:5])
print(takim[:])
# Out:
# Fener
# bahçe
# Fener
# Fenerbahçe

# %%
takim = "Fenerbahçe"

print(takim[0:5])
print(takim[5:])
print(takim[:5])
print(takim[:])
print(takim[::-1])
# Out:
# Fener
# bahçe
# Fener
# Fenerbahçe
# eçhabreneF

# %%
# Objelerin RAM'de depolanması

#heap
import sys

sayi = 123456
print(sys.getsizeof(sayi))

str1 = "Python Eğitimi"
print(sys.getsizeof(str1))
# Out:
# 28
# 86

# %%
x = "100"
y = 120.99

print(int(x) + int(y))
print(float(x) + y)
# Out:
# 220
# 220.99

# %%
# Kullanıcıdan girdi alma

# input() fonksiyonu 

isim = input("Lütfen adınızı giriniz: ")
print("Merhaba", isim)
# Out:
# Merhaba a

# %%
yas = int(input("Lütfen yaşınızı giriniz: "))
print("Yaşınız:", yas)
# Out:
# Yaşınız: 21

# %%
sayi1 = 60

sayi2 = 30

print(sayi1*sayi2+sayi1/sayi2+sayi1 % sayi2)
# Out:
# 1802.0
