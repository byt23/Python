# %%
ilk_tuple = ("Python",)
print(type(ilk_tuple))
# Out:
# <class 'tuple'>

# %%
kisisel_bilgiler = ("Berkay Turan", 22, True)
print(len(kisisel_bilgiler))
# Out:
# 3

# %%
renkler_listesi = ["kırmızı", "mavi", "yeşil"]
tuple_renk = tuple(renkler_listesi)
print(tuple_renk)
# Out:
# ('kırmızı', 'mavi', 'yeşil')

# %%
programlar = ("Python","Java","C++","Ruby")

print(programlar[2])
print(programlar[-1])
# Out:
# C++
# Ruby

# %%
harfler = ("a", "b", "c", "d", "e", "f", "g")

print(harfler[2:5])
print(harfler[:4])
print(harfler[3:])
# Out:
# ('c', 'd', 'e')
# ('a', 'b', 'c', 'd')
# ('d', 'e', 'f', 'g')

# %%
sepet = ("elma","muz","çilek")

if "muz" in sepet :
    print("Evet, muz sepetin içinde bulunuyor.")
else :
    print("Hayır, muz sepetin içinde bulunmuyor.")
# Out:
# Evet, muz sepetin içinde bulunuyor.

# %%
kitalar = ("Asya", "Avrupa", "Afrika", "Amerika", "Antarktika")
print(kitalar[-2])
# Out:
# Amerika

# %%
sayilar = (10, 20, 30, 40, 50, 60, 70, 80)
print(sayilar[2:6])
# Out:
# (30, 40, 50, 60)

# %%
kullanicilar = ("ahmet", "berna", "cem", "deniz")

if "berna" in kullanicilar :
    print("Kullanıcı bulundu")
# Out:
# Kullanıcı bulundu

# %%
telefonlar = ("Apple","Samsung","Nokia")

gecici_liste = list(telefonlar)
gecici_liste[2] = "Xiaomi"
gecici_liste.append("Huawei")
gecici_liste.remove("Samsung")

telefonlar = tuple(telefonlar)

print(telefonlar)
# Out:
# ('Apple', 'Samsung', 'Nokia')

# %%
notlar = (50,60,70)
yeni_not = (80,)

notlar += yeni_not

print(notlar)
# Out:
# (50, 60, 70, 80)

# %%
sepet = ("Elma","Muz")
del sepet

print(sepet)

# %%
meyveler = ("elma","armut","çilek")
meyveler = list(meyveler)
meyveler[1] = "kavun"

meyveler = tuple(meyveler)

print(meyveler)
# Out:
# ('elma', 'kavun', 'çilek')

# %%
sayilar = (1,2,3)
yeni_sayi = (4,)

sayilar += yeni_sayi

print(sayilar)
# Out:
# (1, 2, 3, 4)

# %%
arabalar = ("Ford", "BMW", "Audi")
arabalar = list(arabalar)
arabalar.remove("BMW")

arabalar = tuple(arabalar)

print(arabalar)
# Out:
# ('Ford', 'Audi')

# %%
bilgiler = ("Ali",25,"Mühendis")

(isim, yas, meslek) = bilgiler

print(isim)
print(meslek)
# Out:
# Ali
# Mühendis

# %%
sayilar = (10,20,30,40,50)

(birinci, ikinci, *digerleri) = sayilar

print(birinci)
print(digerleri)
# Out:
# 10
# [30, 40, 50]

# %%
harfler = ("A","B","C","D","E")

(ilk, *ortadakiler, son) = harfler

print(ilk)
print(son)
print(ortadakiler)
# Out:
# A
# E
# ['B', 'C', 'D']

# %%
koordinatlar = (35.12,42.89)
(enlem,boylam) = koordinatlar

print(enlem)
print(boylam)
# Out:
# 35.12
# 42.89

# %%
skorlar = (100,95,80,75,60)
(şampiyon,ikinci, *diğerleri) = skorlar
print(diğerleri)
# Out:
# [80, 75, 60]

# %%
gunler = ("Pazartesi", "Salı", "Çarşamba", "Perşembe", "Cuma")
(ilk_gun, *ara_gunler, son_gun) = gunler

print(ara_gunler)
# Out:
# ['Salı', 'Çarşamba', 'Perşembe']

# %%
iller = ("Ankara","İzmir","Bursa")

for sehir in iller :
    print(sehir)
# Out:
# Ankara
# İzmir
# Bursa

# %%
oyunlar = ("Satranç","Tavla")

for i in range(len(oyunlar)):
    print(i+1,". index ->",oyunlar[i])
# Out:
# 1 . index -> Satranç
# 2 . index -> Tavla

# %%
notlar = (100,90,85)

i = 0
while i < len(notlar):
    print("Notunuz:", notlar[i])
    i += 1
# Out:
# Notunuz: 100
# Notunuz: 90
# Notunuz: 85

# %%
mevsimler = ("İlkbahar", "Yaz", "Sonbahar", "Kış")

for mevsim in mevsimler:
    print(mevsim)
# Out:
# İlkbahar
# Yaz
# Sonbahar
# Kış

# %%
fiyatlar = (50,100,150)

for fiyat in range(len(fiyatlar)):
    print(fiyat+1,". fiyat :", fiyatlar[fiyat])
# Out:
# 1 . fiyat : 50
# 2 . fiyat : 100
# 3 . fiyat : 150

# %%
markalar = ("Apple", "Samsung", "Sony")
i = 0

while i < len(markalar):
    print(i + 1 ,". marka :", markalar[i])
    i += 1
# Out:
# 1 . marka : Apple
# 2 . marka : Samsung
# 3 . marka : Sony

# %%
harfler = ("a","b","c")
sayilar = (1,2,3)

kombinasyon = harfler + sayilar

print(kombinasyon)
# Out:
# ('a', 'b', 'c', 1, 2, 3)

# %%
sesler = ("bip","bop")
tekrarli_sesler = sesler * 3

print(tekrarli_sesler)
# Out:
# ('bip', 'bop', 'bip', 'bop', 'bip', 'bop')

# %%
anket_demeti = ("Evet","Hayır","Evet","Evet","Belki")
print(anket_demeti.count("Evet"))
# Out:
# 3

# %%
harf_demeti = ("A", "B", "C", "D")
print(harf_demeti.index("C"))
# Out:
# 2

# %%
tek_sayilar = (1,3,5)
cift_sayilar = (2,4,6)

tum_sayilar = tek_sayilar + cift_sayilar

print(tum_sayilar)
# Out:
# (1, 3, 5, 2, 4, 6)

# %%
kelimeler = ("Python", "Harika")
yeni_kelimeler = kelimeler * 4
print(yeni_kelimeler)
# Out:
# ('Python', 'Harika', 'Python', 'Harika', 'Python', 'Harika', 'Python', 'Harika')

# %%
baslangic = ("Merhaba",)
bitis = ("Dünya",)
sonuc = (baslangic + bitis) * 5
print(sonuc)
# Out:
# ('Merhaba', 'Dünya', 'Merhaba', 'Dünya', 'Merhaba', 'Dünya', 'Merhaba', 'Dünya', 'Merhaba', 'Dünya')
